# %%
import numpy as np
eps_start = 1
eps_end = 0.01
eps_decay1 = 2500
eps_decay2 = 0.995
eps2 = 1
for i in range(1500):
    # eps_threshold = max(self.eps['END'], self.eps['START'] - self.steps_done * 1e-5)
    eps1 = eps_end + (eps_start - eps_end) * np.exp(-1. * i / eps_decay1)
    # eps = 
    eps2 = max(eps_end,eps2*eps_decay2)
    if i % 100 == 99 or i < 10:
        print(f"i: {i}, eps1, : {eps1} , eps2, : {eps2} diff : {eps1 - eps2}")
# Out:
# i: 0, eps1, : 1.0 , eps2, : 0.995 diff : 0.0050000000000000044
# i: 1, eps1, : 0.999604079189441 , eps2, : 0.990025 diff : 0.009579079189441009
# i: 2, eps1, : 0.9992083167155369 , eps2, : 0.985074875 diff : 0.014133441715536876
# i: 3, eps1, : 0.9988127125149655 , eps2, : 0.9801495006250001 diff : 0.018663211889965448
# i: 4, eps1, : 0.9984172665244303 , eps2, : 0.9752487531218751 diff : 0.023168513402555213
# i: 5, eps1, : 0.9980219786806598 , eps2, : 0.9703725093562657 diff : 0.02764946932439405
# i: 6, eps1, : 0.997626848920408 , eps2, : 0.9655206468094844 diff : 0.03210620211092363
# i: 7, eps1, : 0.997231877180454 , eps2, : 0.960693043575437 diff : 0.036538833605017085
# i: 8, eps1, : 0.9968370633976026 , eps2, : 0.9558895783575597 diff : 0.040947485040042864
# i: 9, eps1, : 0.9964424075086834 , eps2, : 0.9511101304657719 diff : 0.04533227704291154
# i: 99, eps1, : 0.9615620934833748 , eps2, : 0.6057704364907278 diff : 0.35579165699264703
# ...
